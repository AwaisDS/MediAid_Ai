# %%
import pandas as pd
import seaborn as sns

# %%
dic={
    'name':['awais','ali','ahmed'],
    'age':[23,44,32]
}

# %%
df=pd.DataFrame(dic)

# %%
sns.barplot(data=df,x=df.name,y=df.age)
# Out:
# <Axes: xlabel='name', ylabel='age'>
