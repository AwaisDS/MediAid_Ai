# %%
import pandas as pd

# %%
df=pd.read_csv('medi_aid_synthetic.csv',index_col=0)

# %%
df.head()
# Out:
#             age  gender              region  duration_days   comorbidity  \
# patient_id
# P0001        15    Male    Gilgit-Baltistan              9           NaN
# P0002        74    Male    Gilgit-Baltistan              3           NaN
# P0003        19  Female               Sindh              8  Hypertension
# P0004        39   Other           Islamabad             20           NaN
# P0005        29    Male  Khyber Pakhtunkhwa              1           NaN
#
#                  disease                                   present_symptoms  \
# patient_id
# P0001            Measles  conjunctivitis;constipation;cough;fever;rash;r...
# P0002        Hepatitis C  abdominal_pain;chest_pain;dark_urine;jaundice;...
# P0003           COVID-19  cough;fatigue;fever;shortness_of_breath;sore_t...
# P0004            Measles                    cough;fever;headache;runny_nose
# P0005       Tuberculosis     chest_pain;dark_urine;night_sweats;weight_loss
#
# ...

# %%
df['disease'].value_counts()
# Out:
# disease
# Gastroenteritis            51
# Hepatitis C                49
# Typhoid                    48
# Measles                    44
# Chickenpox                 44
# Tuberculosis               44
# Malaria                    42
# Urinary_Tract_Infection    41
# Hepatitis A                38
# Pneumonia                  35
# COVID-19                   32
# Dengue                     32
# Name: count, dtype: int64

# %%
print(df.dtypes)
# Out:
# age                       int64
# gender                   object
# region                   object
# duration_days             int64
# comorbidity              object
# disease                  object
# present_symptoms         object
# recommended_tests        object
# recommended_medicines    object
# abdominal_pain            int64
# back_pain                 int64
# chest_pain                int64
# chills                    int64
# conjunctivitis            int64
# constipation              int64
# cough                     int64
# dark_urine                int64
# dehydration               int64
# diarrhea                  int64
# dysuria                   int64
# fatigue                   int64
# fever                     int64
# frequency                 int64
# headache                  int64
# itching                   int64
# jaundice                  int64
# joint_pain                int64
# loss_of_appetite          int64
# loss_of_smell_taste       int64
# ...
